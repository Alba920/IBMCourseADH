# %% [markdown]
# # Statistics for Data Science with Python

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
boston_df.describe(include="all")
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %% [markdown]
# ## Become familiar with the dataset

# %% [markdown]
# The following describes the dataset variables:
#
# ·      CRIM - per capita crime rate by town
#
# ·      ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# ·      INDUS - proportion of non-retail business acres per town.
#
# ·      CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# ·      NOX - nitric oxides concentration (parts per 10 million)
#
# ·      RM - average number of rooms per dwelling
#
# ·      AGE - proportion of owner-occupied units built prior to 1940
#
# ·      DIS - weighted distances to five Boston employment centres
#
# ·      RAD - index of accessibility to radial highways
#
# ·      TAX - full-value property-tax rate per $10,000
#
# ·      PTRATIO - pupil-teacher ratio by town
#
# ·      LSTAT - % lower status of the population
#
# ·      MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ## Generating Descriptive Statistics and Visualizations

# %% [markdown]
# ### Question 1: For the 'Median value of owner-occupied homes' provide a boxplot

# %%
ax=sns.boxplot(y="MEDV", data=boston_df, color="cyan")
ax.set_title("Owner-occupied homes")
# Out:
# Text(0.5, 1.0, 'Owner-occupied homes')

# %% [markdown]
# The boxplot above shows the median value for the variable MEDV (21.200, as shown in the table above) among with outliers.

# %% [markdown]
# ### Question 2: Provide a histogram for the Charles River variable

# %%
ax2=sns.countplot(x="CHAS", data=boston_df, hue="CHAS", dodge=False, palette="cool")
ax2.set_title("Number of homes near the Charles River", fontsize=20)
ax2.set_xlabel('CHAS', fontsize = 15, color='black')    
ax2.set_ylabel('count', fontsize = 15, color='black')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# This countplot displays the number of homes near the Charles River. Color blue shows the counts for the homes that do not bound the river, while color purple shows the counts for those homes that do bound the river.

# %% [markdown]
# ### Provide a boxplot for the MEDV variable vs the AGE variable

# %% [markdown]
# #### Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'Age_Group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'Age_Group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'Age_Group'] = '70 years and older'

# %%
ax3=sns.boxplot(x="MEDV", y="Age_Group", data=boston_df, palette="YlOrRd", order=["70 years and older", "between 35 and 70 years", "35 years and younger"])
ax3.set_title("Owner-occupied homes among the different age groups", fontsize=20)
ax3.set_xlabel("Owner-occupied homes",  fontsize=12)
ax3.set_ylabel("Age group", fontsize=12)
# Out:
# Text(0, 0.5, 'Age group')

# %% [markdown]
# The boxplot above shows that on average the median value of owner occupied homes is higher when the Age is lower. We can see how the box moves to the right when the Age group is younger.

# %% [markdown]
# ### Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?

# %%
ax4=sns.scatterplot(x="INDUS", y="NOX", data=boston_df, color="red")
ax4.set_title("Realtionship between Nitric oxide concentrations \n and the proportion of non-retail business acres per town", fontsize=20)
ax4.set_xlabel("Proportion of non-retail business acres per town",  fontsize=12)
ax4.set_ylabel("Nitric oxide concentrations", fontsize=12)
# Out:
# Text(0, 0.5, 'Nitric oxide concentrations')

# %% [markdown]
# Values in the bottom-left section of the scatter plot indicate a strong relationship between low Nitric oxide concentrations and low proportion of non-retail business acres per town.
#
# Generally, a higher proprtion of non-retail business acres per town produce a higher concentration of Nitric oxide.

# %% [markdown]
# ### Create a histogram for the pupil to teacher ratio variable

# %%
ax5=sns.countplot(x="PTRATIO", data=boston_df)
ax5.set_title("Pupil to teacher ratio variable", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pupil to teacher ratio variable')

# %% [markdown]
# ## Test for statistics

# %% [markdown]
# ### Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %% [markdown]
# Hypothesis:
#
# Null Hypothesis -> There's no significant difference in the median value between houses bounded and not bounded by the Charles River
#
# Alternative Hypothesis -> There's a significant difference in the median value between houses bounded and not bounded by the Charles River

# %%
boston_df.loc[(boston_df['CHAS'] == 0), 'CHAS_T'] = 'FAR'
boston_df.loc[(boston_df['CHAS'] == 1), 'CHAS_T'] = 'NEAR'
boston_df.head(5)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV                Age_Group CHAS_T
# 0  296.0     15.3   4.98  24.0  between 35 and 70 years    FAR
# 1  242.0     17.8   9.14  21.6       70 years and older    FAR
# 2  242.0     17.8   4.03  34.7  between 35 and 70 years    FAR
# 3  222.0     18.7   2.94  33.4  between 35 and 70 years    FAR
# 4  222.0     18.7   5.33  36.2  between 35 and 70 years    FAR

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS_T'] == 'FAR']['MEDV'], 
                      boston_df[boston_df['CHAS_T'] == 'NEAR']['MEDV'], equal_var = True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# Given that the p-value is less than 0.05, we have enough evidence to reject the Null Hypothesis, meaning there is not a statistical difference in median value between houses near the Charles River and houses far away

# %% [markdown]
# ### Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %% [markdown]
# Hypothesis
#
# Null Hypotesis: There isn't statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940
#
# Alternative Hypothesis: There is statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# Given that the p-value is less than 0.05, we have enough evidence to reject the Null Hypothesis --> There is statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940

# %% [markdown]
# ### Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %% [markdown]
# Null Hypothesis: Nitric Oxide concentration is not correlated with the proportion of non-retail business acres per town
#
# Alternative Hypothesis: Nitric Oxide concentration is correlated with the proportion of non-retail business acres per town

# %%
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# (0.7636514469209151, 7.913361061238693e-98)

# %% [markdown]
# Given that the Pearson Coefficient is 0.76365 and the p-value less than 0.05, we have enough evidence to reject the Null Hypothesis as there is a positive correlation between Nitric oxide concentration and proportion of non-retail business acres per town. This positive relationship is supported by the Scatter plot shown before.

# %% [markdown]
# ### What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %%
x = boston_df['DIS']
y = boston_df['MEDV']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predisction = model.predict(x)

model.summary()
# Out:
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Mon, 30 May 2022   Prob (F-statistic):           1.21e-08
# Time:                        09:54:54   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# The coef DIS of 1.0916 indicates that an additional weighted distance to the 5 empolyment centers in boston increases of 1.0916 the median value of owner occupied homes
